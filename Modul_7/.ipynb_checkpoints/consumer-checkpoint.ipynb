# %%
from dataclasses import dataclass

@dataclass
class Ride:
    PULocationID: int
    DOLocationID: int
    trip_distance: float
    total_amount: float
    lpep_pickup_datetime: int

# %%
import json

def ride_deserializer(data):
    json_str = data.decode('utf-8')
    ride_dict = json.loads(json_str)
    return Ride(**ride_dict)

# %%
test_bytes = json.dumps({
    'PULocationID': 186,
    'DOLocationID': 79,
    'trip_distance': 1.72,
    'total_amount': 17.31,
    'lpep_pickup_datetime': 1730429702000
}).encode('utf-8')

ride_deserializer(test_bytes)
# Ride(PULocationID=186, DOLocationID=79, trip_distance=1.72,
#      total_amount=17.31, tpep_pickup_datetime=1730429702000)
# Out:
# Ride(PULocationID=186, DOLocationID=79, trip_distance=1.72, total_amount=17.31, lpep_pickup_datetime=1730429702000)

# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-q3',   
    value_deserializer=ride_deserializer
)

# %%
from datetime import datetime

print(f"Listening to {topic_name}...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.lpep_pickup_datetime / 1000)
    print(f"Received: PU={ride.PULocationID}, DO={ride.DOLocationID}, "
          f"distance={ride.trip_distance}, amount=${ride.total_amount:.2f}, "
          f"pickup={pickup_dt}")
    count += 1
    # if count >= 10:
    #     print(f"\n... received {count} messages so far (stopping after 10 for demo)")
    #     break

consumer.close()
# Out:
# Listening to rides...
# Received: PU=247, DO=69, distance=0.7, amount=$10.00, pickup=2025-10-01 08:21:47
# Received: PU=247, DO=69, distance=0.7, amount=$10.00, pickup=2025-10-01 08:21:47
# Received: PU=247, DO=69, distance=0.7, amount=$10.00, pickup=2025-10-01 08:21:47
# Received: PU=66, DO=25, distance=1.61, amount=$16.68, pickup=2025-10-01 08:14:03
# Received: PU=244, DO=244, distance=0.0, amount=$13.20, pickup=2025-10-01 08:16:44
# Received: PU=95, DO=170, distance=10.37, amount=$67.85, pickup=2025-10-01 08:07:36
# Received: PU=82, DO=138, distance=4.07, amount=$34.12, pickup=2025-10-01 05:10:29
# Received: PU=129, DO=37, distance=7.13, amount=$47.12, pickup=2025-10-01 05:49:46
# Received: PU=95, DO=134, distance=1.13, amount=$13.88, pickup=2025-10-01 08:11:24
# Received: PU=95, DO=70, distance=6.01, amount=$34.32, pickup=2025-10-01 08:07:08
# Received: PU=181, DO=137, distance=6.45, amount=$41.88, pickup=2025-10-01 08:36:08
# Received: PU=74, DO=236, distance=1.74, amount=$17.46, pickup=2025-10-01 08:26:55
# Received: PU=75, DO=41, distance=1.13, amount=$12.48, pickup=2025-10-01 08:37:32
# Received: PU=95, DO=80, distance=8.37, amount=$91.00, pickup=2025-10-01 07:56:56
# Received: PU=75, DO=75, distance=1.35, amount=$11.40, pickup=2025-10-01 08:03:38
# Received: PU=33, DO=225, distance=6.07, amount=$37.68, pickup=2025-10-01 08:12:52
# Received: PU=154, DO=265, distance=15.98, amount=$61.50, pickup=2025-10-01 08:12:19
# Received: PU=75, DO=74, distance=1.65, amount=$12.20, pickup=2025-10-01 15:36:56
# Received: PU=74, DO=140, distance=2.98, amount=$26.85, pickup=2025-10-01 15:47:40
# Received: PU=41, DO=244, distance=2.49, amount=$17.22, pickup=2025-10-02 15:44:33
# Received: PU=74, DO=42, distance=1.33, amount=$15.70, pickup=2025-10-01 15:43:10
# Received: PU=74, DO=41, distance=1.68, amount=$13.60, pickup=2025-10-01 15:13:38
# Received: PU=74, DO=239, distance=3.62, amount=$31.38, pickup=2025-10-01 15:41:56
# Received: PU=74, DO=75, distance=1.03, amount=$12.96, pickup=2025-10-01 15:30:31
# Received: PU=74, DO=75, distance=1.65, amount=$19.90, pickup=2025-10-01 15:50:22
# Received: PU=74, DO=166, distance=1.63, amount=$17.16, pickup=2025-10-01 15:14:32
# Received: PU=74, DO=42, distance=1.03, amount=$11.10, pickup=2025-10-01 15:40:24
# Received: PU=166, DO=238, distance=1.5, amount=$12.10, pickup=2025-10-01 15:28:00
# Received: PU=166, DO=75, distance=2.9, amount=$19.90, pickup=2025-10-01 15:46:57
# Received: PU=74, DO=75, distance=1.5, amount=$17.16, pickup=2025-10-01 15:39:28
# Received: PU=7, DO=202, distance=2.63, amount=$20.52, pickup=2025-10-01 15:33:54
# Received: PU=74, DO=244, distance=4.39, amount=$31.44, pickup=2025-10-01 15:14:00
# Received: PU=74, DO=75, distance=1.56, amount=$15.64, pickup=2025-10-01 15:28:52
# Received: PU=74, DO=166, distance=1.23, amount=$13.20, pickup=2025-10-01 15:53:14
# Received: PU=74, DO=75, distance=1.51, amount=$17.16, pickup=2025-10-01 15:24:23
# Received: PU=236, DO=166, distance=2.14, amount=$18.90, pickup=2025-10-01 15:38:13
# Received: PU=130, DO=53, distance=6.53, amount=$31.80, pickup=2025-10-01 15:47:58
# Received: PU=74, DO=42, distance=1.22, amount=$13.80, pickup=2025-10-01 15:30:14
# Received: PU=74, DO=75, distance=1.37, amount=$17.00, pickup=2025-10-01 15:53:10
# Received: PU=41, DO=75, distance=1.11, amount=$13.50, pickup=2025-10-01 15:42:28
# Received: PU=74, DO=262, distance=3.03, amount=$27.46, pickup=2025-10-01 15:22:22
# Received: PU=75, DO=161, distance=2.8, amount=$20.60, pickup=2025-10-01 15:50:45
# Received: PU=146, DO=230, distance=2.74, amount=$41.20, pickup=2025-10-01 16:49:14
# Received: PU=74, DO=166, distance=1.61, amount=$13.60, pickup=2025-10-01 16:44:25
# Received: PU=74, DO=75, distance=1.07, amount=$17.00, pickup=2025-10-01 16:09:43
# Received: PU=74, DO=75, distance=1.57, amount=$20.52, pickup=2025-10-01 16:37:40
# Received: PU=74, DO=75, distance=1.56, amount=$22.08, pickup=2025-10-01 16:42:35
# Received: PU=74, DO=41, distance=0.7, amount=$10.00, pickup=2025-10-01 16:39:53
# Received: PU=166, DO=239, distance=1.97, amount=$18.85, pickup=2025-10-01 16:08:05
# Received: PU=75, DO=74, distance=1.42, amount=$13.50, pickup=2025-10-01 16:03:57
# Received: PU=74, DO=75, distance=1.6, amount=$19.50, pickup=2025-10-01 16:13:10
# Received: PU=75, DO=74, distance=0.78, amount=$8.70, pickup=2025-10-01 16:32:11
# Received: PU=74, DO=75, distance=1.56, amount=$17.00, pickup=2025-10-01 16:43:41
# Received: PU=116, DO=68, distance=6.66, amount=$38.10, pickup=2025-10-01 16:42:03
# Received: PU=244, DO=243, distance=0.4, amount=$5.90, pickup=2025-10-01 16:46:31
# Received: PU=74, DO=138, distance=6.7, amount=$52.49, pickup=2025-10-01 16:18:33
# Received: PU=75, DO=262, distance=0.15, amount=$12.90, pickup=2025-10-01 16:51:52
# Received: PU=134, DO=135, distance=1.68, amount=$13.60, pickup=2025-10-01 16:48:23
# Received: PU=74, DO=263, distance=2.12, amount=$24.25, pickup=2025-10-01 16:10:44
# Received: PU=74, DO=75, distance=1.74, amount=$22.20, pickup=2025-10-01 16:05:29
# Received: PU=74, DO=75, distance=1.72, amount=$21.38, pickup=2025-10-01 16:43:21
# Received: PU=75, DO=143, distance=3.13, amount=$25.45, pickup=2025-10-01 16:57:42
# Received: PU=75, DO=42, distance=1.34, amount=$10.80, pickup=2025-10-01 16:13:03
# Received: PU=74, DO=75, distance=1.61, amount=$18.00, pickup=2025-10-01 16:37:12
# Received: PU=74, DO=24, distance=2.33, amount=$19.10, pickup=2025-10-01 16:44:38
# Received: PU=223, DO=138, distance=3.39, amount=$21.40, pickup=2025-10-01 17:59:47
# Received: PU=130, DO=10, distance=1.83, amount=$15.00, pickup=2025-10-01 17:47:18
# Received: PU=166, DO=41, distance=0.66, amount=$9.18, pickup=2025-10-01 17:05:30
# Received: PU=74, DO=236, distance=2.03, amount=$24.66, pickup=2025-10-01 17:28:08
# Received: PU=74, DO=75, distance=1.08, amount=$15.30, pickup=2025-10-01 17:10:38
# Received: PU=74, DO=43, distance=1.67, amount=$17.16, pickup=2025-10-01 17:49:02
# Received: PU=129, DO=231, distance=13.51, amount=$43.50, pickup=2025-10-01 17:12:28
# Received: PU=74, DO=75, distance=1.57, amount=$23.14, pickup=2025-10-01 17:24:38
# Received: PU=74, DO=43, distance=1.6, amount=$17.15, pickup=2025-10-01 17:15:10
# Received: PU=43, DO=162, distance=2.6, amount=$24.97, pickup=2025-10-01 17:33:01
# Received: PU=74, DO=236, distance=1.76, amount=$23.06, pickup=2025-10-01 17:03:33
# Received: PU=74, DO=75, distance=1.57, amount=$14.19, pickup=2025-10-01 17:57:28
# Received: PU=95, DO=121, distance=2.51, amount=$18.70, pickup=2025-10-01 17:02:19
# Received: PU=75, DO=75, distance=0.74, amount=$12.10, pickup=2025-10-01 17:45:12
# Received: PU=166, DO=74, distance=1.6, amount=$17.10, pickup=2025-10-01 17:13:21
# Received: PU=43, DO=100, distance=3.95, amount=$37.32, pickup=2025-10-01 17:15:26
# Received: PU=74, DO=116, distance=2.22, amount=$21.38, pickup=2025-10-01 17:44:52
# Received: PU=74, DO=140, distance=3.69, amount=$33.90, pickup=2025-10-01 17:56:51
# Received: PU=82, DO=82, distance=1.2, amount=$10.80, pickup=2025-10-01 17:53:53
# Received: PU=74, DO=239, distance=3.86, amount=$34.74, pickup=2025-10-01 17:05:54
# Received: PU=82, DO=129, distance=0.0, amount=$20.10, pickup=2025-10-01 17:53:12
# Received: PU=74, DO=247, distance=2.4, amount=$19.68, pickup=2025-10-01 17:30:10
# Received: PU=33, DO=106, distance=2.7, amount=$22.20, pickup=2025-10-01 17:25:23
# Received: PU=75, DO=41, distance=1.11, amount=$9.40, pickup=2025-10-01 17:31:25
# Received: PU=74, DO=75, distance=1.27, amount=$12.90, pickup=2025-10-01 17:46:03
# Received: PU=74, DO=43, distance=3.0, amount=$37.94, pickup=2025-10-01 17:11:27
# Received: PU=74, DO=78, distance=7.01, amount=$33.20, pickup=2025-10-01 17:21:23
# Received: PU=74, DO=75, distance=1.43, amount=$18.10, pickup=2025-10-01 17:06:42
# Received: PU=75, DO=74, distance=0.71, amount=$8.76, pickup=2025-10-01 17:20:55
# Received: PU=74, DO=237, distance=2.96, amount=$30.54, pickup=2025-10-01 17:48:19
# Received: PU=74, DO=236, distance=1.92, amount=$24.35, pickup=2025-10-01 17:24:23
# Received: PU=75, DO=41, distance=1.59, amount=$15.25, pickup=2025-10-01 17:54:01
# Received: PU=197, DO=134, distance=1.53, amount=$20.20, pickup=2025-10-01 17:02:34
# Received: PU=74, DO=236, distance=2.4, amount=$25.50, pickup=2025-10-01 17:19:29
# Received: PU=74, DO=75, distance=1.64, amount=$19.10, pickup=2025-10-01 17:17:50
# Received: PU=74, DO=140, distance=3.26, amount=$36.42, pickup=2025-10-01 16:36:12
# Received: PU=43, DO=163, distance=3.28, amount=$34.50, pickup=2025-10-01 17:12:06
# Received: PU=75, DO=263, distance=1.33, amount=$18.69, pickup=2025-10-01 17:19:35
# Received: PU=75, DO=229, distance=3.45, amount=$27.80, pickup=2025-10-01 17:48:09
# Received: PU=74, DO=166, distance=1.71, amount=$16.32, pickup=2025-10-01 17:30:23
# Received: PU=41, DO=159, distance=2.67, amount=$25.60, pickup=2025-10-01 17:49:46
# Received: PU=263, DO=132, distance=18.95, amount=$101.97, pickup=2025-10-01 17:00:29
# Received: PU=129, DO=260, distance=4.6, amount=$38.10, pickup=2025-10-01 17:09:24
# Received: PU=130, DO=130, distance=1.02, amount=$12.12, pickup=2025-10-01 17:24:11
# Received: PU=41, DO=75, distance=1.65, amount=$14.64, pickup=2025-10-01 17:48:12
# Received: PU=74, DO=236, distance=1.76, amount=$23.06, pickup=2025-10-01 17:37:55
# Received: PU=33, DO=256, distance=7.01, amount=$40.68, pickup=2025-10-01 17:14:25
# Received: PU=74, DO=247, distance=2.01, amount=$15.70, pickup=2025-10-01 17:23:30
# Received: PU=243, DO=239, distance=6.37, amount=$32.45, pickup=2025-10-01 17:14:26
# Received: PU=74, DO=236, distance=2.43, amount=$24.75, pickup=2025-10-01 17:24:59
# Received: PU=74, DO=75, distance=1.56, amount=$17.50, pickup=2025-10-01 17:00:01
# Received: PU=75, DO=142, distance=3.1, amount=$25.04, pickup=2025-10-01 17:16:07
# Received: PU=134, DO=216, distance=3.23, amount=$24.00, pickup=2025-10-02 00:15:48
# Received: PU=134, DO=216, distance=3.46, amount=$28.56, pickup=2025-10-02 00:48:42
# Received: PU=244, DO=151, distance=3.92, amount=$37.31, pickup=2025-10-02 00:29:31
# Received: PU=55, DO=264, distance=0.0, amount=$14.30, pickup=2025-10-02 00:02:14
# Received: PU=7, DO=7, distance=0.85, amount=$16.38, pickup=2025-10-02 00:00:32
# Received: PU=75, DO=262, distance=1.4, amount=$20.10, pickup=2025-10-02 00:29:45
# Received: PU=75, DO=74, distance=1.35, amount=$21.84, pickup=2025-10-02 00:45:54
# Received: PU=244, DO=74, distance=3.9, amount=$30.30, pickup=2025-10-02 00:13:31
# Received: PU=74, DO=43, distance=3.0, amount=$39.95, pickup=2025-10-02 00:40:18
# Received: PU=166, DO=236, distance=2.32, amount=$28.15, pickup=2025-10-02 00:19:16
# Received: PU=166, DO=41, distance=1.51, amount=$20.79, pickup=2025-10-02 00:52:13
# Received: PU=75, DO=140, distance=1.83, amount=$25.98, pickup=2025-10-02 00:37:16
# Received: PU=74, DO=75, distance=1.54, amount=$16.40, pickup=2025-10-02 00:04:42
# Received: PU=43, DO=236, distance=1.22, amount=$19.45, pickup=2025-10-01 23:57:56
# Received: PU=263, DO=145, distance=5.49, amount=$39.80, pickup=2025-10-02 00:22:33
# Received: PU=43, DO=239, distance=1.96, amount=$24.30, pickup=2025-10-02 00:08:34
# Received: PU=75, DO=74, distance=1.4, amount=$20.12, pickup=2025-10-02 00:34:14
# Received: PU=95, DO=196, distance=1.25, amount=$18.48, pickup=2025-10-02 00:13:19
# Received: PU=95, DO=170, distance=10.26, amount=$67.90, pickup=2025-10-02 00:54:23
# Received: PU=74, DO=41, distance=1.24, amount=$15.00, pickup=2025-10-02 00:31:00
# Received: PU=25, DO=97, distance=1.53, amount=$20.60, pickup=2025-10-02 00:06:38
# Received: PU=95, DO=135, distance=2.25, amount=$20.30, pickup=2025-10-02 00:20:30
# Received: PU=130, DO=10, distance=1.69, amount=$14.70, pickup=2025-10-01 23:57:24
# Received: PU=130, DO=215, distance=1.85, amount=$21.56, pickup=2025-10-02 00:23:36
# Received: PU=223, DO=223, distance=0.7, amount=$13.40, pickup=2025-10-02 00:56:28
# Received: PU=43, DO=151, distance=1.63, amount=$19.11, pickup=2025-10-02 01:40:48
# Received: PU=43, DO=141, distance=1.54, amount=$21.00, pickup=2025-10-02 00:26:04
# Received: PU=74, DO=237, distance=2.79, amount=$34.94, pickup=2025-10-02 00:39:39
# Received: PU=75, DO=164, distance=0.0, amount=$32.34, pickup=2025-10-02 00:23:00
# Received: PU=82, DO=129, distance=1.58, amount=$20.16, pickup=2025-10-01 23:57:33
# Received: PU=75, DO=236, distance=0.66, amount=$11.20, pickup=2025-10-02 00:07:30
# Received: PU=75, DO=262, distance=1.87, amount=$25.98, pickup=2025-10-02 00:29:16
# Received: PU=236, DO=229, distance=2.75, amount=$35.28, pickup=2025-10-02 00:28:29
# Received: PU=74, DO=42, distance=1.9, amount=$17.50, pickup=2025-10-02 00:11:53
# Received: PU=74, DO=239, distance=3.4, amount=$25.85, pickup=2025-10-02 00:59:45
# Received: PU=75, DO=236, distance=0.63, amount=$17.44, pickup=2025-10-02 00:16:33
# Received: PU=75, DO=74, distance=1.42, amount=$20.30, pickup=2025-10-02 00:54:52
# Received: PU=33, DO=195, distance=1.58, amount=$20.16, pickup=2025-10-02 00:35:16
# Received: PU=75, DO=43, distance=1.07, amount=$19.55, pickup=2025-10-02 00:48:04
# Received: PU=166, DO=151, distance=0.7, amount=$11.50, pickup=2025-10-02 00:17:35
# Received: PU=43, DO=236, distance=1.87, amount=$23.46, pickup=2025-10-02 00:51:39
# Received: PU=82, DO=83, distance=0.43, amount=$8.40, pickup=2025-10-02 00:53:32
# Received: PU=75, DO=75, distance=0.47, amount=$9.80, pickup=2025-10-02 00:29:41
# Received: PU=24, DO=138, distance=8.09, amount=$72.50, pickup=2025-10-02 00:06:01
# Received: PU=95, DO=95, distance=0.82, amount=$12.60, pickup=2025-10-02 00:46:05
# Received: PU=82, DO=82, distance=0.05, amount=$7.00, pickup=2025-10-02 00:31:25
# Received: PU=260, DO=252, distance=7.6, amount=$38.10, pickup=2025-10-02 00:46:53
# Received: PU=97, DO=62, distance=2.51, amount=$27.12, pickup=2025-10-02 00:27:12
# Received: PU=65, DO=17, distance=1.97, amount=$23.30, pickup=2025-10-02 00:09:51
# Received: PU=82, DO=56, distance=2.26, amount=$19.60, pickup=2025-10-02 00:11:15
# Received: PU=82, DO=129, distance=0.67, amount=$13.30, pickup=2025-10-02 00:42:22
# Received: PU=66, DO=261, distance=2.42, amount=$29.40, pickup=2025-10-02 00:03:53
# Received: PU=130, DO=112, distance=10.65, amount=$60.48, pickup=2025-10-02 00:23:41
# Received: PU=129, DO=264, distance=5.01, amount=$37.62, pickup=2025-10-02 00:53:29
# Received: PU=97, DO=33, distance=1.8, amount=$24.50, pickup=2025-10-02 00:43:24
# Received: PU=95, DO=82, distance=3.08, amount=$25.20, pickup=2025-10-02 00:13:54
# Received: PU=74, DO=41, distance=1.01, amount=$17.64, pickup=2025-10-02 00:15:07
# Received: PU=74, DO=236, distance=1.87, amount=$19.55, pickup=2025-10-02 00:41:16
# Received: PU=75, DO=236, distance=0.63, amount=$11.20, pickup=2025-10-02 01:00:54
# Received: PU=264, DO=264, distance=0.0, amount=$20.00, pickup=2025-10-02 00:23:37
# Received: PU=129, DO=70, distance=1.78, amount=$21.84, pickup=2025-10-02 00:31:18
# Received: PU=74, DO=116, distance=2.4, amount=$18.90, pickup=2025-10-02 00:40:03
# Received: PU=41, DO=166, distance=1.01, amount=$12.60, pickup=2025-10-02 00:18:43
# Received: PU=166, DO=166, distance=1.07, amount=$12.60, pickup=2025-10-02 00:28:46
# Received: PU=75, DO=263, distance=0.63, amount=$17.58, pickup=2025-10-02 00:18:22
# Received: PU=75, DO=200, distance=9.93, amount=$72.22, pickup=2025-10-02 00:39:01
# Received: PU=95, DO=95, distance=0.94, amount=$14.70, pickup=2025-10-02 00:05:13
# Received: PU=236, DO=142, distance=2.1, amount=$20.94, pickup=2025-10-03 00:06:34
# Received: PU=74, DO=237, distance=2.78, amount=$32.70, pickup=2025-10-02 00:37:24
# Received: PU=74, DO=138, distance=6.8, amount=$60.42, pickup=2025-10-02 00:04:40
# Received: PU=95, DO=95, distance=0.46, amount=$12.40, pickup=2025-10-02 00:33:39
# Received: PU=74, DO=263, distance=2.62, amount=$28.50, pickup=2025-10-02 00:11:25
# Received: PU=130, DO=265, distance=6.31, amount=$50.40, pickup=2025-10-02 00:09:36
# Received: PU=75, DO=74, distance=1.05, amount=$14.40, pickup=2025-10-02 00:51:08
# Received: PU=82, DO=138, distance=3.85, amount=$32.40, pickup=2025-10-02 00:49:52
# Received: PU=83, DO=129, distance=1.26, amount=$15.40, pickup=2025-10-02 00:30:51
# Received: PU=82, DO=129, distance=2.54, amount=$31.20, pickup=2025-10-02 00:49:28
# Received: PU=75, DO=238, distance=1.65, amount=$20.55, pickup=2025-10-02 00:17:20
# Received: PU=166, DO=143, distance=3.07, amount=$35.15, pickup=2025-10-02 00:46:26
# Received: PU=75, DO=74, distance=1.46, amount=$17.64, pickup=2025-10-02 00:01:25
# Received: PU=75, DO=74, distance=1.53, amount=$23.66, pickup=2025-10-02 00:46:15
# Received: PU=134, DO=95, distance=2.15, amount=$39.90, pickup=2025-10-02 00:26:10
# Received: PU=244, DO=162, distance=7.98, amount=$52.81, pickup=2025-10-02 00:11:55
# Received: PU=74, DO=42, distance=0.89, amount=$18.48, pickup=2025-10-02 00:13:58
# Received: PU=74, DO=262, distance=2.28, amount=$25.14, pickup=2025-10-02 00:58:35
# Received: PU=65, DO=89, distance=3.5, amount=$31.05, pickup=2025-10-02 00:19:17
# Received: PU=43, DO=237, distance=1.96, amount=$26.82, pickup=2025-10-02 00:31:55
# Received: PU=43, DO=68, distance=6.04, amount=$47.04, pickup=2025-10-02 00:09:50
# Received: PU=95, DO=196, distance=1.34, amount=$15.96, pickup=2025-10-02 00:34:02
# Received: PU=42, DO=246, distance=5.83, amount=$44.52, pickup=2025-10-02 00:05:45
# Received: PU=43, DO=239, distance=2.06, amount=$18.85, pickup=2025-10-02 00:21:13
# Received: PU=75, DO=48, distance=3.94, amount=$30.80, pickup=2025-10-02 01:49:32
# Received: PU=75, DO=42, distance=2.9, amount=$28.55, pickup=2025-10-02 01:29:35
# Received: PU=223, DO=7, distance=0.04, amount=$7.70, pickup=2025-10-02 01:07:08
# Received: PU=130, DO=112, distance=10.54, amount=$63.84, pickup=2025-10-02 01:36:51
# Received: PU=130, DO=171, distance=7.53, amount=$51.90, pickup=2025-10-02 01:26:11
# Received: PU=97, DO=49, distance=1.29, amount=$21.00, pickup=2025-10-02 01:48:12
# Received: PU=129, DO=7, distance=2.0, amount=$20.30, pickup=2025-10-02 01:03:43
# Received: PU=75, DO=42, distance=2.27, amount=$24.50, pickup=2025-10-02 01:16:43
# Received: PU=97, DO=33, distance=1.19, amount=$18.48, pickup=2025-10-02 01:17:23
# Received: PU=74, DO=140, distance=4.2, amount=$29.40, pickup=2025-10-02 01:06:09
# Received: PU=75, DO=74, distance=1.24, amount=$18.90, pickup=2025-10-02 01:15:21
# Received: PU=74, DO=75, distance=1.63, amount=$15.70, pickup=2025-10-02 01:56:26
# Received: PU=75, DO=50, distance=4.15, amount=$29.70, pickup=2025-10-02 01:00:25
# Received: PU=223, DO=223, distance=0.72, amount=$14.56, pickup=2025-10-02 01:55:17
# Received: PU=41, DO=166, distance=1.14, amount=$15.00, pickup=2025-10-02 01:56:28
# Received: PU=97, DO=61, distance=1.8, amount=$21.60, pickup=2025-10-02 01:37:23
# Received: PU=189, DO=40, distance=1.57, amount=$14.70, pickup=2025-10-02 02:03:19
# Received: PU=66, DO=113, distance=7.32, amount=$55.44, pickup=2025-10-02 01:09:33
# Received: PU=74, DO=151, distance=2.31, amount=$23.10, pickup=2025-10-02 01:36:23
# Received: PU=75, DO=74, distance=1.9, amount=$27.95, pickup=2025-10-02 01:02:41
# Received: PU=74, DO=264, distance=2.8, amount=$31.00, pickup=2025-10-02 01:55:19
# Received: PU=74, DO=41, distance=1.2, amount=$14.70, pickup=2025-10-02 01:49:26
# Received: PU=43, DO=151, distance=1.53, amount=$14.70, pickup=2025-10-02 01:08:02
# Received: PU=166, DO=116, distance=1.9, amount=$24.57, pickup=2025-10-02 01:22:39
# Received: PU=41, DO=41, distance=0.83, amount=$10.50, pickup=2025-10-02 01:53:05
# Received: PU=82, DO=138, distance=3.68, amount=$28.70, pickup=2025-10-02 01:06:11
# Received: PU=82, DO=138, distance=3.62, amount=$32.04, pickup=2025-10-02 01:34:23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 6
#       3 print(f"Listening to {topic_name}...")
#       5 count = 0
# ----> 6 for message in consumer:
#       7     ride = message.value
#       8     pickup_dt = datetime.fromtimestamp(ride.lpep_pickup_datetime / 1000)
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
count = 0
processed = 0

for message in consumer:
    ride = message.value
    
    if ride.trip_distance > 5:
        count += 1
    
    processed += 1
    
    if processed == 1000:   # dataset hanya 1000 record
        break

print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 4
#       1 count = 0
#       2 processed = 0
# ----> 4 for message in consumer:
#       5     ride = message.value
#       7     if ride.trip_distance > 10:
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/github/Zoomcamp-DE-2026/Modul_7/.venv/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
